# %% [markdown]
# # Multiple Linear Regression - Exercise

# %% [markdown]
# You are given a real estate dataset.
#
# Real estate is one of those examples that every regression course goes through as it is extremely easy to understand and there is a (almost always) certain causal relationship to be found.
#
# The data is located in the file: 'real_estate_price_size_year.csv'.
#
# You are expected to create a multiple linear regression (similar to the one in the lecture), using the new data.
#
# In this exercise, the dependent variable is 'price', while the independent variables are 'size' and 'year'.
#
# Good luck!

# %% [markdown]
# ## Import the relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
sns.set()

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('real_estate_price_size_year.csv')

# %%
data
# Out:
#          price     size  year
# 0   234314.144   643.09  2015
# 1   228581.528   656.22  2009
# 2   281626.336   487.29  2018
# 3   401255.608  1504.75  2015
# 4   458674.256  1275.46  2009
# ..         ...      ...   ...
# 95  252460.400   549.80  2009
# 96  310522.592  1037.44  2009
# 97  383635.568  1504.75  2006
# 98  225145.248   648.29  2015
# 99  274922.856   705.29  2006
#
# [100 rows x 3 columns]

# %%
data.describe()
# Out:
#                price         size         year
# count     100.000000   100.000000   100.000000
# mean   292289.470160   853.024200  2012.600000
# std     77051.727525   297.941951     4.729021
# min    154282.128000   479.750000  2006.000000
# 25%    234280.148000   643.330000  2009.000000
# 50%    280590.716000   696.405000  2015.000000
# 75%    335723.696000  1029.322500  2018.000000
# max    500681.128000  1842.510000  2018.000000

# %% [markdown]
# ## Create the regression

# %% [markdown]
# ### Declare the dependent and the independent variables

# %%
y = data['price']
x1 = data[['size','year']]

# %% [markdown]
# ### Regression

# %%
x = sm.add_constant(x1)
result = sm.OLS(y,x).fit()
result.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                       Results: Ordinary least squares
# ===========================================================================
# Model:                  OLS                Adj. R-squared:       0.772
# Dependent Variable:     price              AIC:                  2389.4035
# Date:                   2024-02-04 21:25   BIC:                  2397.2190
# No. Observations:       100                Log-Likelihood:       -1191.7
# Df Model:               2                  F-statistic:          168.5
# Df Residuals:           97                 Prob (F-statistic):   2.77e-32
# R-squared:              0.776              Scale:                1.3544e+09
# ---------------------------------------------------------------------------
#           Coef.       Std.Err.      t    P>|t|      [0.025        0.975]
# ---------------------------------------------------------------------------
# const -5772267.0175 1582772.6618 -3.6469 0.0004 -8913632.6174 -2630901.4176
# size       227.7009      12.4740 18.2541 0.0000      202.9435      252.4582
# year      2916.7853     785.8957  3.7114 0.0003     1357.0000     4476.5707
# ---------------------------------------------------------------------------
# Omnibus:                  10.083          Durbin-Watson:             2.250
# Prob(Omnibus):            0.006           Jarque-Bera (JB):          3.678
# Skew:                     0.095           Prob(JB):                  0.159
# Kurtosis:                 2.080           Condition No.:             941440
# ===========================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is
# correctly specified.
# [2] The condition number is large, 9.41e+05. This might indicate
# that there are strong multicollinearity or other numerical
# problems.
# """
